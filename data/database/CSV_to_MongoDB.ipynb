# %%
# Modules to run code
import csv
import pymongo
import pandas as pd
import ast

# %%
# Import .csv files from Resources folder
birds_data = pd.read_csv('../Endangered_Birds.csv')
plants_data = pd.read_csv('../Endangered_Plants.csv')
population_data = pd.read_csv('../cleanedPop_lat_Data.csv')
population_data
# Out:
#    State       Pop     density        Lat        Long abbrev  \
# 0     CA  39937500    256.3728  36.778259 -119.417931     CA
# 1     TX  29472300    112.8204  31.000000 -100.000000     TX
# 2     FL  21993000    410.1259  27.994402  -81.760254     FL
# 3     NY  19440500    412.5218  43.000000  -75.000000     NY
# 4     PA  12820900    286.5454  41.203323  -77.194527     PA
# 5     IL  12659700    228.0246  40.000000  -89.000000     IL
# 6     OH  11747700    287.5040  40.367474  -82.996216     OH
# 7     GA  10736100    186.6726  33.247875  -83.441162     GA
# 8     NC  10611900    218.2710  35.782169  -80.793457     NC
# 9     MI  10045000    177.6650  44.182205  -84.506836     MI
# 10    NJ   8936570   1215.1985  39.833851  -74.871826     NJ
# 11    VA   8626210    218.4404  37.926868  -78.024902     VA
# 12    WA   7797100    117.3273  47.751076 -120.740135     WA
# 13    AZ   7378490     64.9549  34.048927 -111.093735     AZ
# 14    MA   6976600    894.4359  42.407211  -71.382439     MA
# 15    TN   6897580    167.2749  35.860119  -86.660156     TN
# 16    IN   6745350    188.2809  40.273502  -86.126976     IN
# 17    MO   6169270     89.7453  38.573936  -92.603760     MO
# 18    MD   6083120    626.6735  39.045753  -76.641273     MD
# 19    WI   5851750    108.0496  44.500000  -89.500000     WI
# 20    CO   5845530     56.4012  39.113014 -105.358887     CO
# 21    MN   5700670     71.5922  46.392410  -94.636230     MN
# 22    SC   5210100    173.3176  33.836082  -81.163727     SC
# 23    AL   4908620     96.9221  32.318230  -86.902298     AL
# 24    LA   4645180    107.5174  30.391830  -92.329100     LA
# 25    KY   4499690    113.9566  37.839333  -84.270020     KY
# 26    OR   4301090     44.8086  44.000000 -120.500000     OR
# 27    OK   3954820     57.6546  36.084621  -96.921387     OK
# 28    CT   3563080    735.8695  41.599998  -72.699997     CT
# 29    UT   3282120     39.9430  39.419220 -111.950684     UT
# 30    IA   3179850     56.9284  42.032974  -93.581543     IA
# 31    NV   3139660     28.5993  39.876019 -117.224121     NV
# 32    AR   3039000     58.4030  34.799999  -92.199997     AR
# 33    PR   3032160    876.6002        NaN         NaN     PR
# 34    MS   2989260     63.7056  33.000000  -90.000000     MS
# 35    KS   2910360     35.5968  38.500000  -98.000000     KS
# 36    NM   2096640     17.2850  34.307144 -106.018066     NM
# 37    NE   1952570     25.4161  41.500000 -100.000000     NE
# 38    ID   1826160     22.0970  44.068203 -114.742043     ID
# 39    WV   1778070     73.9691  39.000000  -80.500000     WV
# 40    HI   1412690    219.9424  19.741755 -155.844437     HI
# 41    NH   1371250    153.1610  44.000000  -71.500000     NH
# 42    ME   1345790     43.6336  45.367584  -68.972168     ME
# 43    MT   1086760      7.4668  46.965260 -109.533691     MT
# 44    RI   1056160   1021.4313  41.700001  -71.500000     RI
# 45    DE    982895    504.3073  39.000000  -75.500000     DE
# 46    SD    903027     11.9116  44.500000 -100.000000     SD
# 47    ND    761723     11.0393  47.650589 -100.437012     ND
# 48    AK    734002      1.2863  66.160507 -153.369141     AK
# 49    DC    720687  11814.5410        NaN         NaN     DC
# 50    VT    628061     68.1416  44.000000  -72.699997     VT
# 51    WY    567025      5.8400  43.075970 -107.290283     WY
#
#                                                bounds          type
# 0   [[[-123.233256| 42.006186]| [-122.378853| 42.0...       Polygon
# 1   [[[-101.812942| 36.501861]| [-100.000075| 36.5...       Polygon
# 2   [[[-85.497137| 30.997536]| [-85.004212| 31.003...       Polygon
# 3   [[[-73.343806| 45.013027]| [-73.332852| 44.804...       Polygon
# 4   [[[-79.76278| 42.252649]| [-79.76278| 42.00070...       Polygon
# 5   [[[-90.639984| 42.510065]| [-88.788778| 42.493...       Polygon
# 6   [[[-80.518598| 41.978802]| [-80.518598| 40.636...       Polygon
# 7   [[[-83.109191| 35.00118]| [-83.322791| 34.7875...       Polygon
# 8   [[[-80.978661| 36.562108]| [-80.294043| 36.545...       Polygon
# 9   [[[[-83.454238| 41.732339]| [-84.807042| 41.69...  MultiPolygon
# 10  [[[-74.236547| 41.14083]| [-73.902454| 40.9984...       Polygon
# 11  [[[[-75.397659| 38.013497]| [-75.244304| 38.02...  MultiPolygon
# 12  [[[[-117.033359| 49.000239]| [-117.044313| 47....  MultiPolygon
# 13  [[[-109.042503| 37.000263]| [-109.04798| 31.33...       Polygon
# 14  [[[-70.917521| 42.887974]| [-70.818936| 42.871...       Polygon
# 15  [[[-88.054868| 36.496384]| [-88.071299| 36.677...       Polygon
# 16  [[[-85.990061| 41.759724]| [-84.807042| 41.759...       Polygon
# 17  [[[-91.833957| 40.609566]| [-91.729895| 40.615...       Polygon
# 18  [[[[-75.994645| 37.95325]| [-76.016553| 37.953...  MultiPolygon
# 19  [[[-90.415429| 46.568478]| [-90.229213| 46.508...       Polygon
# 20  [[[-107.919731| 41.003906]| [-105.728954| 40.9...       Polygon
# 21  [[[-92.014696| 46.705401]| [-92.091373| 46.749...       Polygon
# 22  [[[-82.764143| 35.066903]| [-82.550543| 35.160...       Polygon
# 23  [[[-87.359296| 35.00118]| [-85.606675| 34.9847...       Polygon
# 24  [[[-93.608485| 33.018527]| [-91.16577| 33.0020...       Polygon
# 25  [[[-83.903347| 38.769315]| [-83.678792| 38.632...       Polygon
# 26  [[[-123.211348| 46.174138]| [-123.11824| 46.18...       Polygon
# 27  [[[-100.087706| 37.000263]| [-94.616242| 37.00...       Polygon
# 28  [[[-73.053528| 42.039048]| [-71.799309| 42.022...       Polygon
# 29  [[[-112.164359| 41.995232]| [-111.047063| 42.0...       Polygon
# 30  [[[-91.368417| 43.501391]| [-91.215062| 43.501...       Polygon
# 31  [[[-117.027882| 42.000709]| [-114.04295| 41.99...       Polygon
# 32  [[[-94.473842| 36.501861]| [-90.152536| 36.496...       Polygon
# 33  [[[-66.448338| 17.984326]| [-66.771478| 18.006...       Polygon
# 34  [[[-88.471115| 34.995703]| [-88.202745| 34.995...       Polygon
# 35  [[[-101.90605| 40.001626]| [-95.306337| 40.001...       Polygon
# 36  [[[-107.421329| 37.000263]| [-106.868158| 36.9...       Polygon
# 37  [[[-103.324578| 43.002989]| [-101.626726| 42.9...       Polygon
# 38  [[[-116.04751| 49.000239]| [-116.04751| 47.976...       Polygon
# 39  [[[-80.518598| 40.636951]| [-80.518598| 39.722...       Polygon
# 40  [[[[-155.634835| 18.948267]| [-155.881297| 19....  MultiPolygon
# 41  [[[-71.08183| 45.303304]| [-71.032537| 44.6570...       Polygon
# 42  [[[-70.703921| 43.057759]| [-70.824413| 43.128...       Polygon
# 43  [[[-104.047534| 49.000239]| [-104.042057| 47.8...       Polygon
# 44  [[[[-71.196845| 41.67757]| [-71.120168| 41.496...  MultiPolygon
# 45  [[[-75.414089| 39.804456]| [-75.507197| 39.683...       Polygon
# 46  [[[-104.047534| 45.944106]| [-96.560556| 45.93...       Polygon
# 47  [[[-97.228743| 49.000239]| [-97.097296| 48.682...       Polygon
# 48  [[[[-131.602021| 55.117982]| [-131.569159| 55....  MultiPolygon
# 49  [[[-77.035264| 38.993869]| [-76.909294| 38.895...       Polygon
# 50  [[[-71.503554| 45.013027]| [-71.4926| 44.91444...       Polygon
# 51  [[[-109.080842| 45.002073]| [-105.91517| 45.00...       Polygon

# %%
# Establish connection to local host 27017
conn = 'mongodb://localhost:27017'

# Connect to MongoClient
client = pymongo.MongoClient(conn)

# Begin by dropping any previous version of the MongoDB instance.
# client.drop_database('Endangered_Birds')

# %%
# Create database by naming db here
db = client.Endangered_Species

# Create collection by naming collection here
bird_collection = db.birds
plants_collection = db.plants
population_collection = db.population

# %%
# Use ".to_dict('records')"in combination with .csv variable to create list of dictionaries data set
birds_data.reset_index(inplace=True)
plants_data.reset_index(inplace=True)
population_data.reset_index(inplace=True)

birds_data_dict = birds_data.to_dict('records')
plants_data_dict = plants_data.to_dict('records')
population_data_dict = population_data.to_dict('records')

# %%
# Insert data from the 'data_dict' variable into the collection using 'collection' variable
bird_collection.insert_many(birds_data_dict)
plants_collection.insert_many(plants_data_dict)
population_collection.insert_many(population_data_dict)

# %%
# CODE TO PRINT OUT CONTENTS OF THE DATABASE

# Store dataset now contained in the collection using the collection's name
query = db.birds.find()

# Use a for loop to confirm data is now located in the database
for x in query:
    print(x)
# Out:
# {'_id': ObjectId('5f9f0d57e148386c85a20464'), 'index': 0, 'State': 'WI', 'Lat': 44.5, 'Long': -89.5, 'Organism Type': 'Bird', 'Species Name': "Kirtland's Warbler", 'Federal Status': 'Endangered', 'Unit Name': 'St. Croix WMD'}
# {'_id': ObjectId('5f9f0d57e148386c85a20465'), 'index': 1, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': "Attwater's Greater Prairie-chicken", 'Federal Status': 'Endangered', 'Unit Name': 'Attwater Prairie Chicken NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20466'), 'index': 2, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': "Attwater's Greater Prairie-chicken", 'Federal Status': 'Endangered', 'Unit Name': 'Aransas NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20467'), 'index': 3, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Black-capped Vireo', 'Federal Status': 'Endangered', 'Unit Name': 'Santa Ana NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20468'), 'index': 4, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Black-capped Vireo', 'Federal Status': 'Endangered', 'Unit Name': 'Balcones Canyonlands NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20469'), 'index': 5, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Santa Ana NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2046a'), 'index': 6, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Aransas NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2046b'), 'index': 7, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'San Bernard NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2046c'), 'index': 8, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Laguna Atascosa NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2046d'), 'index': 9, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Lower Rio Grande Valley NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2046e'), 'index': 10, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Big Boggy NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2046f'), 'index': 11, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Cactus Ferruginous Pygmy-owl', 'Federal Status': 'Endangered', 'Unit Name': 'Lower Rio Grande Valley NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20470'), 'index': 12, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Cactus Ferruginous pygmy-owl', 'Federal Status': 'Endangered', 'Unit Name': 'Laguna Atascosa NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20471'), 'index': 13, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Eskimo Curlew', 'Federal Status': 'Endangered', 'Unit Name': 'Lower Rio Grande Valley NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20472'), 'index': 14, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Golden-cheeked Warbler', 'Federal Status': 'Endangered', 'Unit Name': 'Balcones Canyonlands NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20473'), 'index': 15, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Golden-cheeked Warbler', 'Federal Status': 'Endangered', 'Unit Name': 'Lower Rio Grande Valley NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20474'), 'index': 16, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Golden-cheeked Warbler', 'Federal Status': 'Endangered', 'Unit Name': 'Santa Ana NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20475'), 'index': 17, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Buffalo Lake NWR (TX)'}
# {'_id': ObjectId('5f9f0d57e148386c85a20476'), 'index': 18, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Hagerman NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20477'), 'index': 19, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Northern Aplomado Falcon', 'Federal Status': 'Endangered', 'Unit Name': 'Laguna Atascosa NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20478'), 'index': 20, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Northern Aplomado Falcon', 'Federal Status': 'Threatened', 'Unit Name': 'Lower Rio Grande Valley NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20479'), 'index': 21, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Northern Aplomado Falcon', 'Federal Status': 'Endangered', 'Unit Name': 'Santa Ana NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2047a'), 'index': 22, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Brazoria NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2047b'), 'index': 23, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Aransas NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2047c'), 'index': 24, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Anahuac NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2047d'), 'index': 25, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Big Boggy NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2047e'), 'index': 26, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Santa Ana NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2047f'), 'index': 27, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Texas Point NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20480'), 'index': 28, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'San Bernard NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20481'), 'index': 29, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'McFaddin NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20482'), 'index': 30, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Laguna Atascosa NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20483'), 'index': 31, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Lower Rio Grande Valley NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20484'), 'index': 32, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Hagerman NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20485'), 'index': 33, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Trinity River NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20486'), 'index': 34, 'State': 'TX', 'Lat': 31.0, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Whooping Crane', 'Federal Status': 'Endangered', 'Unit Name': 'Aransas NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20487'), 'index': 35, 'State': 'SD', 'Lat': 44.5, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Sand Lake NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20488'), 'index': 36, 'State': 'SD', 'Lat': 44.5, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Sand Lake WMD'}
# {'_id': ObjectId('5f9f0d57e148386c85a20489'), 'index': 37, 'State': 'SD', 'Lat': 44.5, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Lacreek NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2048a'), 'index': 38, 'State': 'SD', 'Lat': 44.5, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Sand Lake WMD'}
# {'_id': ObjectId('5f9f0d57e148386c85a2048b'), 'index': 39, 'State': 'SD', 'Lat': 44.5, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Sand Lake NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2048c'), 'index': 40, 'State': 'SD', 'Lat': 44.5, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Whooping Crane', 'Federal Status': 'Endangered', 'Unit Name': 'Lake Andes WMD'}
# {'_id': ObjectId('5f9f0d57e148386c85a2048d'), 'index': 41, 'State': 'SD', 'Lat': 44.5, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Whooping Crane', 'Federal Status': 'Endangered', 'Unit Name': 'Lake Andes NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2048e'), 'index': 42, 'State': 'RI', 'Lat': 41.700001, 'Long': -71.5, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Sachuest Point NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2048f'), 'index': 43, 'State': 'RI', 'Lat': 41.700001, 'Long': -71.5, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Trustom Pond NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20490'), 'index': 44, 'State': 'RI', 'Lat': 41.700001, 'Long': -71.5, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Ninigret NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20491'), 'index': 45, 'State': 'RI', 'Lat': 41.700001, 'Long': -71.5, 'Organism Type': 'Bird', 'Species Name': 'Roseate Tern', 'Federal Status': 'Endangered', 'Unit Name': 'Ninigret NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20492'), 'index': 46, 'State': 'RI', 'Lat': 41.700001, 'Long': -71.5, 'Organism Type': 'Bird', 'Species Name': 'Roseate Tern', 'Federal Status': 'Endangered', 'Unit Name': 'Trustom Pond NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20493'), 'index': 47, 'State': 'OR', 'Lat': 44.0, 'Long': -120.5, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Siletz Bay NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20494'), 'index': 48, 'State': 'OR', 'Lat': 44.0, 'Long': -120.5, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Three Arch Rocks NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20495'), 'index': 49, 'State': 'OR', 'Lat': 44.0, 'Long': -120.5, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Oregon Islands NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20496'), 'index': 50, 'State': 'OR', 'Lat': 44.0, 'Long': -120.5, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Bandon Marsh NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20497'), 'index': 51, 'State': 'OR', 'Lat': 44.0, 'Long': -120.5, 'Organism Type': 'Bird', 'Species Name': 'Marbled Murrelet', 'Federal Status': 'Threatened', 'Unit Name': 'Cape Meares NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20498'), 'index': 52, 'State': 'OR', 'Lat': 44.0, 'Long': -120.5, 'Organism Type': 'Bird', 'Species Name': 'Northern Spotted Owl', 'Federal Status': 'Threatened', 'Unit Name': 'Cape Meares NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20499'), 'index': 53, 'State': 'OR', 'Lat': 44.0, 'Long': -120.5, 'Organism Type': 'Bird', 'Species Name': 'Western Snowy Plover (Pacific coast population)', 'Federal Status': 'Threatened', 'Unit Name': 'Bandon Marsh NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2049a'), 'index': 54, 'State': 'NY', 'Lat': 43.0, 'Long': -75.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Elizabeth A. Morton NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2049b'), 'index': 55, 'State': 'NY', 'Lat': 43.0, 'Long': -75.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Amagansett NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2049c'), 'index': 56, 'State': 'NY', 'Lat': 43.0, 'Long': -75.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Endangered', 'Unit Name': 'Target Rock NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2049d'), 'index': 57, 'State': 'NY', 'Lat': 43.0, 'Long': -75.0, 'Organism Type': 'Bird', 'Species Name': 'Roseate Tern', 'Federal Status': 'Endangered', 'Unit Name': 'Elizabeth A. Morton NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2049e'), 'index': 58, 'State': 'NE', 'Lat': 41.5, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Boyer Chute NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2049f'), 'index': 59, 'State': 'NE', 'Lat': 41.5, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Rainwater Basin WMD'}
# {'_id': ObjectId('5f9f0d57e148386c85a204a0'), 'index': 60, 'State': 'NE', 'Lat': 41.5, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Rainwater Basin WMD'}
# {'_id': ObjectId('5f9f0d57e148386c85a204a1'), 'index': 61, 'State': 'NE', 'Lat': 41.5, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Whooping Crane', 'Federal Status': 'Endangered', 'Unit Name': 'Rainwater Basin WMD'}
# {'_id': ObjectId('5f9f0d57e148386c85a204a2'), 'index': 62, 'State': 'NE', 'Lat': 41.5, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Whooping Crane', 'Federal Status': 'Endangered', 'Unit Name': 'Valentine NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204a3'), 'index': 63, 'State': 'NE', 'Lat': 41.5, 'Long': -100.0, 'Organism Type': 'Bird', 'Species Name': 'Whooping Crane', 'Federal Status': 'Endangered', 'Unit Name': 'Fort Niobrara NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204a4'), 'index': 64, 'State': 'KS', 'Lat': 38.5, 'Long': -98.0, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Marais des Cygnes NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204a5'), 'index': 65, 'State': 'KS', 'Lat': 38.5, 'Long': -98.0, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Quivira NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204a6'), 'index': 66, 'State': 'KS', 'Lat': 38.5, 'Long': -98.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Quivira NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204a7'), 'index': 67, 'State': 'KS', 'Lat': 38.5, 'Long': -98.0, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Marais des Cygnes NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204a8'), 'index': 68, 'State': 'KS', 'Lat': 38.5, 'Long': -98.0, 'Organism Type': 'Bird', 'Species Name': 'Whooping Crane', 'Federal Status': 'Endangered', 'Unit Name': 'Quivira NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204a9'), 'index': 69, 'State': 'KS', 'Lat': 38.5, 'Long': -98.0, 'Organism Type': 'Bird', 'Species Name': 'Whooping Crane', 'Federal Status': 'Endangered', 'Unit Name': 'Kirwin NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204aa'), 'index': 70, 'State': 'MS', 'Lat': 33.0, 'Long': -90.0, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Mathews Brake NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204ab'), 'index': 71, 'State': 'MS', 'Lat': 33.0, 'Long': -90.0, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Hillside NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204ac'), 'index': 72, 'State': 'MS', 'Lat': 33.0, 'Long': -90.0, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Yazoo NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204ad'), 'index': 73, 'State': 'MS', 'Lat': 33.0, 'Long': -90.0, 'Organism Type': 'Bird', 'Species Name': 'Least Tern Interior', 'Federal Status': 'Endangered', 'Unit Name': 'St. Catherine Creek NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204ae'), 'index': 74, 'State': 'MS', 'Lat': 33.0, 'Long': -90.0, 'Organism Type': 'Bird', 'Species Name': 'Mississippi Sandhill Crane', 'Federal Status': 'Endangered', 'Unit Name': 'Mississippi Sandhill Crane NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204af'), 'index': 75, 'State': 'MS', 'Lat': 33.0, 'Long': -90.0, 'Organism Type': 'Bird', 'Species Name': 'Red-cockaded Woodpecker', 'Federal Status': 'Endangered', 'Unit Name': 'Noxubee NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204b0'), 'index': 76, 'State': 'MS', 'Lat': 33.0, 'Long': -90.0, 'Organism Type': 'Bird', 'Species Name': 'Red-cockaded Woodpecker', 'Federal Status': 'Endangered', 'Unit Name': 'Mississippi Sandhill Crane NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204b1'), 'index': 77, 'State': 'IL', 'Lat': 40.0, 'Long': -89.0, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Cypress Creek NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204b2'), 'index': 78, 'State': 'CT', 'Lat': 41.599998, 'Long': -72.699997, 'Organism Type': 'Bird', 'Species Name': 'Roseate Tern', 'Federal Status': 'Endangered', 'Unit Name': 'Stewart B. McKinney NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204b3'), 'index': 79, 'State': 'AR', 'Lat': 34.799999, 'Long': -92.199997, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Bald Knob NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204b4'), 'index': 80, 'State': 'AR', 'Lat': 34.799999, 'Long': -92.199997, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Overflow NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204b5'), 'index': 81, 'State': 'AR', 'Lat': 34.799999, 'Long': -92.199997, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Bald Knob NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204b6'), 'index': 82, 'State': 'AR', 'Lat': 34.799999, 'Long': -92.199997, 'Organism Type': 'Bird', 'Species Name': 'Red-cockaded Woodpecker', 'Federal Status': 'Endangered', 'Unit Name': 'Felsenthal NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204b7'), 'index': 83, 'State': 'IN', 'Lat': 40.273502, 'Long': -86.126976, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Patoka River NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204b8'), 'index': 84, 'State': 'MO', 'Lat': 38.573936, 'Long': -92.60376, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Big Muddy National Fish and Wildlife Refuge'}
# {'_id': ObjectId('5f9f0d57e148386c85a204b9'), 'index': 85, 'State': 'MO', 'Lat': 38.573936, 'Long': -92.60376, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Squaw Creek NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204ba'), 'index': 86, 'State': 'MO', 'Lat': 38.573936, 'Long': -92.60376, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Endangered', 'Unit Name': 'Clarence Cannon NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204bb'), 'index': 87, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': "Audubon's Crested Caracara", 'Federal Status': 'Threatened', 'Unit Name': 'Arthur R. Marshall Loxahatchee NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204bc'), 'index': 88, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Everglade Snail Kite', 'Federal Status': 'Endangered', 'Unit Name': 'Arthur R. Marshall Loxahatchee NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204bd'), 'index': 89, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Everglade Snail Kite', 'Federal Status': 'Endangered', 'Unit Name': 'Florida Panther NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204be'), 'index': 90, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Everglade Snail Kite', 'Federal Status': 'Endangered', 'Unit Name': 'Lake Woodruff NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204bf'), 'index': 91, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Florida Scrub Jay', 'Federal Status': 'Threatened', 'Unit Name': 'Lake Woodruff NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204c0'), 'index': 92, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Florida Scrub Jay', 'Federal Status': 'Threatened', 'Unit Name': 'Hobe Sound NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204c1'), 'index': 93, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Florida Scrub Jay', 'Federal Status': 'Threatened', 'Unit Name': 'Lower Suwannee NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204c2'), 'index': 94, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Florida Scrub Jay', 'Federal Status': 'Threatened', 'Unit Name': 'Merritt Island NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204c3'), 'index': 95, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Florida Scrub Jay', 'Federal Status': 'Threatened', 'Unit Name': 'Lake Wales Ridge NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204c4'), 'index': 96, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Cedar Keys NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204c5'), 'index': 97, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Merritt Island NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204c6'), 'index': 98, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Lower Suwannee NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204c7'), 'index': 99, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Hobe Sound NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204c8'), 'index': 100, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'St. Marks NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204c9'), 'index': 101, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'St. Vincent NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204ca'), 'index': 102, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Red-cockaded Woodpecker', 'Federal Status': 'Endangered', 'Unit Name': 'St. Marks NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204cb'), 'index': 103, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Red-cockaded Woodpecker', 'Federal Status': 'Endangered', 'Unit Name': 'Florida Panther NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204cc'), 'index': 104, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Roseate Tern', 'Federal Status': 'Threatened', 'Unit Name': 'Merritt Island NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204cd'), 'index': 105, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Roseate Tern', 'Federal Status': 'Threatened', 'Unit Name': 'Key West NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204ce'), 'index': 106, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Wood Stork', 'Federal Status': 'Endangered', 'Unit Name': 'Ten Thousand Islands NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204cf'), 'index': 107, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Wood Stork', 'Federal Status': 'Endangered', 'Unit Name': 'Pine Island NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204d0'), 'index': 108, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Wood Stork', 'Federal Status': 'Endangered', 'Unit Name': 'Lake Woodruff NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204d1'), 'index': 109, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Wood Stork', 'Federal Status': 'Endangered', 'Unit Name': 'Hobe Sound NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204d2'), 'index': 110, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Wood Stork', 'Federal Status': 'Endangered', 'Unit Name': 'J. N. "Ding" Darling NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204d3'), 'index': 111, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Wood Stork', 'Federal Status': 'Endangered', 'Unit Name': 'Florida Panther NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204d4'), 'index': 112, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Wood Stork', 'Federal Status': 'Endangered', 'Unit Name': 'National Key Deer Refuge'}
# {'_id': ObjectId('5f9f0d57e148386c85a204d5'), 'index': 113, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Wood Stork', 'Federal Status': 'Endangered', 'Unit Name': 'Merritt Island NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204d6'), 'index': 114, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Wood Stork', 'Federal Status': 'Endangered', 'Unit Name': 'Lower Suwannee NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204d7'), 'index': 115, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Wood Stork', 'Federal Status': 'Endangered', 'Unit Name': 'St. Marks NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204d8'), 'index': 116, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Wood Stork', 'Federal Status': 'Endangered', 'Unit Name': 'St. Johns NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204d9'), 'index': 117, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Wood Stork', 'Federal Status': 'Endangered', 'Unit Name': 'St. Vincent NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204da'), 'index': 118, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Wood Stork', 'Federal Status': 'Endangered', 'Unit Name': 'Pinellas NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204db'), 'index': 119, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Wood Stork', 'Federal Status': 'Endangered', 'Unit Name': 'Caloosahatchee NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204dc'), 'index': 120, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Wood Stork', 'Federal Status': 'Endangered', 'Unit Name': 'Pelican Island NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204dd'), 'index': 121, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Wood Stork', 'Federal Status': 'Endangered', 'Unit Name': 'Crocodile Lake NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204de'), 'index': 122, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Wood Stork', 'Federal Status': 'Endangered', 'Unit Name': 'Chassahowitzka NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204df'), 'index': 123, 'State': 'FL', 'Lat': 27.994402, 'Long': -81.760254, 'Organism Type': 'Bird', 'Species Name': 'Wood Stork', 'Federal Status': 'Endangered', 'Unit Name': 'Arthur R. Marshall Loxahatchee NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204e0'), 'index': 124, 'State': 'ME', 'Lat': 45.367584, 'Long': -68.97216800000001, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Rachel Carson NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204e1'), 'index': 125, 'State': 'ME', 'Lat': 45.367584, 'Long': -68.97216800000001, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Pond Island NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204e2'), 'index': 126, 'State': 'ME', 'Lat': 45.367584, 'Long': -68.97216800000001, 'Organism Type': 'Bird', 'Species Name': 'Roseate Tern', 'Federal Status': 'Endangered', 'Unit Name': 'Rachel Carson NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204e3'), 'index': 127, 'State': 'ME', 'Lat': 45.367584, 'Long': -68.97216800000001, 'Organism Type': 'Bird', 'Species Name': 'Roseate Tern', 'Federal Status': 'Endangered', 'Unit Name': 'Petit Manan NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204e4'), 'index': 128, 'State': 'ME', 'Lat': 45.367584, 'Long': -68.97216800000001, 'Organism Type': 'Bird', 'Species Name': 'Roseate Tern', 'Federal Status': 'Endangered', 'Unit Name': 'Pond Island NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204e5'), 'index': 129, 'State': 'MI', 'Lat': 44.182205, 'Long': -84.50683599999998, 'Organism Type': 'Bird', 'Species Name': "Kirtland's Warbler", 'Federal Status': 'Endangered', 'Unit Name': 'Kirtlands Warbler WMA'}
# {'_id': ObjectId('5f9f0d57e148386c85a204e6'), 'index': 130, 'State': 'GA', 'Lat': 33.247875, 'Long': -83.441162, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Blackbeard Island NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204e7'), 'index': 131, 'State': 'GA', 'Lat': 33.247875, 'Long': -83.441162, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Wolf Island NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204e8'), 'index': 132, 'State': 'GA', 'Lat': 33.247875, 'Long': -83.441162, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Wassaw NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204e9'), 'index': 133, 'State': 'GA', 'Lat': 33.247875, 'Long': -83.441162, 'Organism Type': 'Bird', 'Species Name': 'Red-cockaded Woodpecker', 'Federal Status': 'Endangered', 'Unit Name': 'Piedmont NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204ea'), 'index': 134, 'State': 'GA', 'Lat': 33.247875, 'Long': -83.441162, 'Organism Type': 'Bird', 'Species Name': 'Wood Stork', 'Federal Status': 'Endangered', 'Unit Name': 'Bond Swamp NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204eb'), 'index': 135, 'State': 'GA', 'Lat': 33.247875, 'Long': -83.441162, 'Organism Type': 'Bird', 'Species Name': 'Wood Stork', 'Federal Status': 'Endangered', 'Unit Name': 'Wolf Island NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204ec'), 'index': 136, 'State': 'GA', 'Lat': 33.247875, 'Long': -83.441162, 'Organism Type': 'Bird', 'Species Name': 'Wood Stork', 'Federal Status': 'Endangered', 'Unit Name': 'Harris Neck NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204ed'), 'index': 137, 'State': 'GA', 'Lat': 33.247875, 'Long': -83.441162, 'Organism Type': 'Bird', 'Species Name': 'Wood Stork', 'Federal Status': 'Endangered', 'Unit Name': 'Wassaw NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204ee'), 'index': 138, 'State': 'GA', 'Lat': 33.247875, 'Long': -83.441162, 'Organism Type': 'Bird', 'Species Name': 'Wood Stork', 'Federal Status': 'Endangered', 'Unit Name': 'Banks Lake NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204ef'), 'index': 139, 'State': 'GA', 'Lat': 33.247875, 'Long': -83.441162, 'Organism Type': 'Bird', 'Species Name': 'Wood Stork', 'Federal Status': 'Endangered', 'Unit Name': 'Blackbeard Island NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204f0'), 'index': 140, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Akiapolaau', 'Federal Status': 'Endangered', 'Unit Name': 'Hakalau Forest NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204f1'), 'index': 141, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Hawaii Akepa', 'Federal Status': 'Endangered', 'Unit Name': 'Hakalau Forest NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204f2'), 'index': 142, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Hawaii Creeper', 'Federal Status': 'Endangered', 'Unit Name': 'Hakalau Forest NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204f3'), 'index': 143, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Hawaiian Common Moorhen', 'Federal Status': 'Endangered', 'Unit Name': 'Hanalei NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204f4'), 'index': 144, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Hawaiian Common Moorhen', 'Federal Status': 'Endangered', 'Unit Name': 'Huleia NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204f5'), 'index': 145, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Hawaiian Common Moorhen', 'Federal Status': 'Endangered', 'Unit Name': 'James Campbell NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204f6'), 'index': 146, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Hawaiian Common Moorhen', 'Federal Status': 'Endangered', 'Unit Name': 'Kakahaia NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204f7'), 'index': 147, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Hawaiian Coot', 'Federal Status': 'Endangered', 'Unit Name': 'Kakahaia NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204f8'), 'index': 148, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Hawaiian Coot', 'Federal Status': 'Endangered', 'Unit Name': 'James Campbell NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204f9'), 'index': 149, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Hawaiian Coot', 'Federal Status': 'Endangered', 'Unit Name': 'Huleia NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204fa'), 'index': 150, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Hawaiian Coot', 'Federal Status': 'Endangered', 'Unit Name': 'Hanalei NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204fb'), 'index': 151, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Hawaiian Coot', 'Federal Status': 'Endangered', 'Unit Name': 'Pearl Harbor NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204fc'), 'index': 152, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Hawaiian coot', 'Federal Status': 'Endangered', 'Unit Name': 'Kealia Pond NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204fd'), 'index': 153, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Hawaiian Duck', 'Federal Status': 'Endangered', 'Unit Name': 'Pearl Harbor NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204fe'), 'index': 154, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Hawaiian Duck', 'Federal Status': 'Endangered', 'Unit Name': 'Hanalei NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a204ff'), 'index': 155, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Hawaiian Duck', 'Federal Status': 'Endangered', 'Unit Name': 'Hakalau Forest NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20500'), 'index': 156, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Hawaiian Duck', 'Federal Status': 'Endangered', 'Unit Name': 'Huleia NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20501'), 'index': 157, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Hawaiian Duck', 'Federal Status': 'Endangered', 'Unit Name': 'James Campbell NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20502'), 'index': 158, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Hawaiian Duck', 'Federal Status': 'Endangered', 'Unit Name': 'Kakahaia NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20503'), 'index': 159, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Hawaiian Goose', 'Federal Status': 'Endangered', 'Unit Name': 'Hakalau Forest NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20504'), 'index': 160, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Hawaiian Hawk', 'Federal Status': 'Endangered', 'Unit Name': 'Hakalau Forest NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20505'), 'index': 161, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Hawaiian Stilt', 'Federal Status': 'Endangered', 'Unit Name': 'Kakahaia NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20506'), 'index': 162, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Hawaiian Stilt', 'Federal Status': 'Endangered', 'Unit Name': 'James Campbell NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20507'), 'index': 163, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Hawaiian Stilt', 'Federal Status': 'Endangered', 'Unit Name': 'Huleia NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20508'), 'index': 164, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Hawaiian Stilt', 'Federal Status': 'Endangered', 'Unit Name': 'Hanalei NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20509'), 'index': 165, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Hawaiian Stilt', 'Federal Status': 'Endangered', 'Unit Name': 'Pearl Harbor NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2050a'), 'index': 166, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Hawaiian stilt', 'Federal Status': 'Endangered', 'Unit Name': 'Kealia Pond NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2050b'), 'index': 167, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Laysan Duck', 'Federal Status': 'Endangered', 'Unit Name': 'Hawaiian Islands NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2050c'), 'index': 168, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Laysan Finch', 'Federal Status': 'Endangered', 'Unit Name': 'Hawaiian Islands NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2050d'), 'index': 169, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Nihoa Finch', 'Federal Status': 'Endangered', 'Unit Name': 'Hawaiian Islands NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2050e'), 'index': 170, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Nihoa Millerbird', 'Federal Status': 'Endangered', 'Unit Name': 'Hawaiian Islands NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2050f'), 'index': 171, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': 'Oahu Elepaio', 'Federal Status': 'Endangered', 'Unit Name': 'Oahu Forest NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20510'), 'index': 172, 'State': 'HI', 'Lat': 19.741755, 'Long': -155.844437, 'Organism Type': 'Bird', 'Species Name': "'O'u (honeycreeper)", 'Federal Status': 'Endangered', 'Unit Name': 'Hakalau Forest NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20511'), 'index': 173, 'State': 'AK', 'Lat': 66.160507, 'Long': -153.36914099999996, 'Organism Type': 'Bird', 'Species Name': 'Spectacled Eider', 'Federal Status': 'Endangered', 'Unit Name': 'Yukon Delta NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20512'), 'index': 174, 'State': 'AK', 'Lat': 66.160507, 'Long': -153.36914099999996, 'Organism Type': 'Bird', 'Species Name': 'Spectacled Eider', 'Federal Status': 'Endangered', 'Unit Name': 'Arctic NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20513'), 'index': 175, 'State': 'AK', 'Lat': 66.160507, 'Long': -153.36914099999996, 'Organism Type': 'Bird', 'Species Name': 'Spectacled Eider', 'Federal Status': 'Endangered', 'Unit Name': 'Alaska Maritime NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20514'), 'index': 176, 'State': 'AK', 'Lat': 66.160507, 'Long': -153.36914099999996, 'Organism Type': 'Bird', 'Species Name': 'Spectacled Eider', 'Federal Status': 'Endangered', 'Unit Name': 'Togiak NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20515'), 'index': 177, 'State': 'AK', 'Lat': 66.160507, 'Long': -153.36914099999996, 'Organism Type': 'Bird', 'Species Name': "Steller's Eider", 'Federal Status': 'Threatened', 'Unit Name': 'Arctic NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20516'), 'index': 178, 'State': 'AK', 'Lat': 66.160507, 'Long': -153.36914099999996, 'Organism Type': 'Bird', 'Species Name': "Steller's Eider", 'Federal Status': 'Threatened', 'Unit Name': 'Alaska Maritime NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20517'), 'index': 179, 'State': 'AK', 'Lat': 66.160507, 'Long': -153.36914099999996, 'Organism Type': 'Bird', 'Species Name': "Steller's Eider", 'Federal Status': 'Threatened', 'Unit Name': 'Alaska Peninsula NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20518'), 'index': 180, 'State': 'AK', 'Lat': 66.160507, 'Long': -153.36914099999996, 'Organism Type': 'Bird', 'Species Name': "Steller's Eider", 'Federal Status': 'Threatened', 'Unit Name': 'Becharof NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20519'), 'index': 181, 'State': 'AK', 'Lat': 66.160507, 'Long': -153.36914099999996, 'Organism Type': 'Bird', 'Species Name': "Steller's Eider", 'Federal Status': 'Threatened', 'Unit Name': 'Izembek NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2051a'), 'index': 182, 'State': 'AK', 'Lat': 66.160507, 'Long': -153.36914099999996, 'Organism Type': 'Bird', 'Species Name': "Steller's Eider", 'Federal Status': 'Threatened', 'Unit Name': 'Kodiak NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2051b'), 'index': 183, 'State': 'AK', 'Lat': 66.160507, 'Long': -153.36914099999996, 'Organism Type': 'Bird', 'Species Name': "Steller's Eider", 'Federal Status': 'Threatened', 'Unit Name': 'Selawik NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2051c'), 'index': 184, 'State': 'AK', 'Lat': 66.160507, 'Long': -153.36914099999996, 'Organism Type': 'Bird', 'Species Name': "Steller's Eider", 'Federal Status': 'Threatened', 'Unit Name': 'Togiak NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2051d'), 'index': 185, 'State': 'AK', 'Lat': 66.160507, 'Long': -153.36914099999996, 'Organism Type': 'Bird', 'Species Name': "Steller's Eider", 'Federal Status': 'Threatened', 'Unit Name': 'Yukon Delta NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2051e'), 'index': 186, 'State': 'TN', 'Lat': 35.860119, 'Long': -86.660156, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Chickasaw NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2051f'), 'index': 187, 'State': 'TN', 'Lat': 35.860119, 'Long': -86.660156, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Cross Creeks NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20520'), 'index': 188, 'State': 'TN', 'Lat': 35.860119, 'Long': -86.660156, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Lower Hatchie NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20521'), 'index': 189, 'State': 'TN', 'Lat': 35.860119, 'Long': -86.660156, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Lake Isom NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20522'), 'index': 190, 'State': 'VA', 'Lat': 37.926868, 'Long': -78.024902, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Back Bay NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20523'), 'index': 191, 'State': 'VA', 'Lat': 37.926868, 'Long': -78.024902, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Fisherman Island NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20524'), 'index': 192, 'State': 'NJ', 'Lat': 39.833851, 'Long': -74.871826, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Edwin B. Forsythe NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20525'), 'index': 193, 'State': 'ND', 'Lat': 47.650589, 'Long': -100.437012, 'Organism Type': 'Bird', 'Species Name': 'Eskimo Curlew', 'Federal Status': 'Endangered', 'Unit Name': 'North Dakota WMA'}
# {'_id': ObjectId('5f9f0d57e148386c85a20526'), 'index': 194, 'State': 'ND', 'Lat': 47.650589, 'Long': -100.437012, 'Organism Type': 'Bird', 'Species Name': 'Interior Least Tern', 'Federal Status': 'Endangered', 'Unit Name': 'North Dakota WMA'}
# {'_id': ObjectId('5f9f0d57e148386c85a20527'), 'index': 195, 'State': 'ND', 'Lat': 47.650589, 'Long': -100.437012, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Lake Nettie NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20528'), 'index': 196, 'State': 'ND', 'Lat': 47.650589, 'Long': -100.437012, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Long Lake NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a20529'), 'index': 197, 'State': 'ND', 'Lat': 47.650589, 'Long': -100.437012, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Audubon WMD'}
# {'_id': ObjectId('5f9f0d57e148386c85a2052a'), 'index': 198, 'State': 'ND', 'Lat': 47.650589, 'Long': -100.437012, 'Organism Type': 'Bird', 'Species Name': 'Least Tern (Interior)', 'Federal Status': 'Endangered', 'Unit Name': 'Audubon NWR'}
# {'_id': ObjectId('5f9f0d57e148386c85a2052b'), 'index': 199, 'State': 'ND', 'Lat': 47.650589, 'Long': -100.437012, 'Organism Type': 'Bird', 'Species Name': 'Mountain Plover', 'Federal Status': 'Proposed', 'Unit Name': 'North Dakota WMA'}
# {'_id': ObjectId('5f9f0d57e148386c85a2052c'), 'index': 200, 'State': 'ND', 'Lat': 47.650589, 'Long': -100.437012, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Buffalo Lake NWR (ND)'}
# {'_id': ObjectId('5f9f0d57e148386c85a2052d'), 'index': 201, 'State': 'ND', 'Lat': 47.650589, 'Long': -100.437012, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Audubon WMD'}
# {'_id': ObjectId('5f9f0d57e148386c85a2052e'), 'index': 202, 'State': 'ND', 'Lat': 47.650589, 'Long': -100.437012, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Cottonwood Lake NWR'}
# ...
# {'_id': ObjectId('5fa0b56b7461968fe02858ed'), 'index': 319, 'State': 'MA', 'Lat': 42.407211, 'Long': -71.382439, 'Organism Type': 'Bird', 'Species Name': 'Roseate Tern', 'Federal Status': 'Endangered', 'Unit Name': 'Mashpee NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe02858ee'), 'index': 320, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'San Diego Bay NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe02858ef'), 'index': 321, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Guadalupe-Nipomo Dunes NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe02858f0'), 'index': 322, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Seal Beach NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe02858f1'), 'index': 323, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Tijuana Slough NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe02858f2'), 'index': 324, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Salinas River NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe02858f3'), 'index': 325, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Sonny Bono Salton Sea NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe02858f4'), 'index': 326, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Don Edwards San Francisco Bay NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe02858f5'), 'index': 327, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'San Pablo Bay NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe02858f6'), 'index': 328, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Farallon NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe02858f7'), 'index': 329, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'California Condor', 'Federal Status': 'Endangered', 'Unit Name': 'Bitter Creek NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe02858f8'), 'index': 330, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'California Condor', 'Federal Status': 'Endangered', 'Unit Name': 'Blue Ridge NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe02858f9'), 'index': 331, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'California Condor', 'Federal Status': 'Endangered', 'Unit Name': 'Hopper Mountain NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe02858fa'), 'index': 332, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Clapper Rail, California', 'Federal Status': 'Endangered', 'Unit Name': 'San Pablo Bay NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe02858fb'), 'index': 333, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Clapper Rail, California', 'Federal Status': 'Endangered', 'Unit Name': 'Don Edwards San Francisco Bay NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe02858fc'), 'index': 334, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Clapper Rail, California', 'Federal Status': 'Endangered', 'Unit Name': 'Farallon NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe02858fd'), 'index': 335, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Clapper Rail, Light-footed', 'Federal Status': 'Endangered', 'Unit Name': 'Tijuana Slough NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe02858fe'), 'index': 336, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Clapper Rail, Light-footed', 'Federal Status': 'Endangered', 'Unit Name': 'San Diego Bay NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe02858ff'), 'index': 337, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Clapper Rail, Light-footed', 'Federal Status': 'Endangered', 'Unit Name': 'Seal Beach NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285900'), 'index': 338, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Clapper Rail, Yuma', 'Federal Status': 'Endangered', 'Unit Name': 'Sonny Bono Salton Sea NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285901'), 'index': 339, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Coastal California Gnatcatcher', 'Federal Status': 'Threatened', 'Unit Name': 'San Diego NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285902'), 'index': 340, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Golden-cheeked Warbler', 'Federal Status': 'Endangered', 'Unit Name': 'Farallon NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285903'), 'index': 341, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': "Least Bell's Vireo", 'Federal Status': 'Endangered', 'Unit Name': 'San Diego Bay NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285904'), 'index': 342, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': "Least Bell's Vireo", 'Federal Status': 'Endangered', 'Unit Name': 'Tijuana Slough NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285905'), 'index': 343, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': "Least Bell's Vireo", 'Federal Status': 'Endangered', 'Unit Name': 'San Diego NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285906'), 'index': 344, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Least Tern, California', 'Federal Status': 'Endangered', 'Unit Name': 'Guadalupe-Nipomo Dunes NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285907'), 'index': 345, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Least Tern, California', 'Federal Status': 'Endangered', 'Unit Name': 'San Diego Bay NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285908'), 'index': 346, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Least Tern, California', 'Federal Status': 'Endangered', 'Unit Name': 'Tijuana Slough NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285909'), 'index': 347, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Least Tern, California', 'Federal Status': 'Endangered', 'Unit Name': 'Seal Beach NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe028590a'), 'index': 348, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Least Tern, California', 'Federal Status': 'Endangered', 'Unit Name': 'Don Edwards San Francisco Bay NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe028590b'), 'index': 349, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Least Tern, California', 'Federal Status': 'Endangered', 'Unit Name': 'San Pablo Bay NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe028590c'), 'index': 350, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Southwestern Willow Flycatcher', 'Federal Status': 'Endangered', 'Unit Name': 'San Diego NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe028590d'), 'index': 351, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Western Snowy Plover (Pacific coast population)', 'Federal Status': 'Threatened', 'Unit Name': 'Humboldt Bay NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe028590e'), 'index': 352, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Western Snowy Plover (Pacific coast population)', 'Federal Status': 'Threatened', 'Unit Name': 'Tijuana Slough NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe028590f'), 'index': 353, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Western Snowy Plover (Pacific coast population)', 'Federal Status': 'Threatened', 'Unit Name': 'San Diego Bay NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285910'), 'index': 354, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Western Snowy Plover (Pacific coast population)', 'Federal Status': 'Threatened', 'Unit Name': 'Guadalupe-Nipomo Dunes NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285911'), 'index': 355, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Western Snowy Plover (Pacific coast population)', 'Federal Status': 'Threatened', 'Unit Name': 'Farallon NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285912'), 'index': 356, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Western Snowy Plover (Pacific coast population)', 'Federal Status': 'Threatened', 'Unit Name': 'Seal Beach NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285913'), 'index': 357, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Western Snowy Plover (Pacific coast population)', 'Federal Status': 'Threatened', 'Unit Name': 'San Pablo Bay NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285914'), 'index': 358, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Western Snowy Plover (Pacific coast population)', 'Federal Status': 'Threatened', 'Unit Name': 'Don Edwards San Francisco Bay NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285915'), 'index': 359, 'State': 'CA', 'Lat': 36.77825900000001, 'Long': -119.417931, 'Organism Type': 'Bird', 'Species Name': 'Western Snowy Plover (Pacific coast population)', 'Federal Status': 'Threatened', 'Unit Name': 'Salinas River NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285916'), 'index': 360, 'State': 'ID', 'Lat': 44.068203, 'Long': -114.742043, 'Organism Type': 'Bird', 'Species Name': 'Whooping Crane', 'Federal Status': 'Endangered', 'Unit Name': 'Bear Lake NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285917'), 'index': 361, 'State': 'ID', 'Lat': 44.068203, 'Long': -114.742043, 'Organism Type': 'Bird', 'Species Name': 'Whooping Crane', 'Federal Status': 'Endangered', 'Unit Name': 'Grays Lake NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285918'), 'index': 362, 'State': 'WY', 'Lat': 43.07597, 'Long': -107.290283, 'Organism Type': 'Bird', 'Species Name': 'Whooping Crane', 'Federal Status': 'Endangered', 'Unit Name': 'National Elk Refuge'}
# {'_id': ObjectId('5fa0b56b7461968fe0285919'), 'index': 363, 'State': 'WY', 'Lat': 43.07597, 'Long': -107.290283, 'Organism Type': 'Bird', 'Species Name': 'Whooping Crane', 'Federal Status': 'Endangered', 'Unit Name': 'Cokeville Meadows NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe028591a'), 'index': 364, 'State': 'NC', 'Lat': 35.782169, 'Long': -80.79345699999998, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Currituck NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe028591b'), 'index': 365, 'State': 'NC', 'Lat': 35.782169, 'Long': -80.79345699999998, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Pea Island NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe028591c'), 'index': 366, 'State': 'NC', 'Lat': 35.782169, 'Long': -80.79345699999998, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Endangered', 'Unit Name': 'Cedar Island NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe028591d'), 'index': 367, 'State': 'NC', 'Lat': 35.782169, 'Long': -80.79345699999998, 'Organism Type': 'Bird', 'Species Name': 'Red-cockaded Woodpecker', 'Federal Status': 'Endangered', 'Unit Name': 'Pee Dee NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe028591e'), 'index': 368, 'State': 'NC', 'Lat': 35.782169, 'Long': -80.79345699999998, 'Organism Type': 'Bird', 'Species Name': 'Red-cockaded Woodpecker', 'Federal Status': 'Endangered', 'Unit Name': 'Alligator River NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe028591f'), 'index': 369, 'State': 'LA', 'Lat': 30.39183, 'Long': -92.3291, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Big Branch Marsh NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285920'), 'index': 370, 'State': 'LA', 'Lat': 30.39183, 'Long': -92.3291, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Bayou Sauvage NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285921'), 'index': 371, 'State': 'LA', 'Lat': 30.39183, 'Long': -92.3291, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Delta NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285922'), 'index': 372, 'State': 'LA', 'Lat': 30.39183, 'Long': -92.3291, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Shell Keys NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285923'), 'index': 373, 'State': 'LA', 'Lat': 30.39183, 'Long': -92.3291, 'Organism Type': 'Bird', 'Species Name': 'Brown Pelican', 'Federal Status': 'Endangered', 'Unit Name': 'Breton NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285924'), 'index': 374, 'State': 'LA', 'Lat': 30.39183, 'Long': -92.3291, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Bayou Sauvage NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285925'), 'index': 375, 'State': 'LA', 'Lat': 30.39183, 'Long': -92.3291, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Threatened', 'Unit Name': 'Breton NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285926'), 'index': 376, 'State': 'LA', 'Lat': 30.39183, 'Long': -92.3291, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Endangered', 'Unit Name': 'Big Branch Marsh NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285927'), 'index': 377, 'State': 'LA', 'Lat': 30.39183, 'Long': -92.3291, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Endangered', 'Unit Name': 'Delta NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285928'), 'index': 378, 'State': 'LA', 'Lat': 30.39183, 'Long': -92.3291, 'Organism Type': 'Bird', 'Species Name': 'Piping Plover', 'Federal Status': 'Endangered', 'Unit Name': 'Shell Keys NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe0285929'), 'index': 379, 'State': 'LA', 'Lat': 30.39183, 'Long': -92.3291, 'Organism Type': 'Bird', 'Species Name': 'Red-cockaded Woodpecker', 'Federal Status': 'Endangered', 'Unit Name': 'Upper Ouachita NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe028592a'), 'index': 380, 'State': 'LA', 'Lat': 30.39183, 'Long': -92.3291, 'Organism Type': 'Bird', 'Species Name': 'Red-cockaded Woodpecker', 'Federal Status': 'Endangered', 'Unit Name': 'Big Branch Marsh NWR'}
# {'_id': ObjectId('5fa0b56b7461968fe028592b'), 'index': 381, 'State': 'LA', 'Lat': 30.39183, 'Long': -92.3291, 'Organism Type': 'Bird', 'Species Name': 'Red-cockaded Woodpecker', 'Federal Status': 'Endangered', 'Unit Name': "D'Arbonne NWR"}
